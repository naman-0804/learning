# %% [markdown]
# <a href="https://colab.research.google.com/github/naman-0804/learning/blob/natural-language-processing/tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

# %%
corpus="""Hello welcome , My name is naman. I am from vit chennai doing btech for last 4 years.
I have been placed in Infosys and TCS digital , but i took only TCS as it had a higher pay than infosys.
My degree is over and i am waiting for joining. Thanks. I don't"""
print(corpus)
# Out:
# Hello welcome , My name is naman. I am from vit chennai doing btech for last 4 years.
# I have been placed in Infosys and TCS digital , but i took only TCS as it had a higher pay than infosys.
# My degree is over and i am waiting for joining. Thanks. I don't

# %%
#corpus to document
document=sent_tokenize(corpus)
print(document)
type(document)
# Out:
# ['Hello welcome , My name is naman.', 'I am from vit chennai doing btech for last 4 years.', 'I have been placed in Infosys and TCS digital , but i took only TCS as it had a higher pay than infosys.', 'My degree is over and i am waiting for joining.', 'Thanks.', "I don't"]
# list

# %%
#corpus to word
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'My',
#  'name',
#  'is',
#  'naman',
#  '.',
#  'I',
#  'am',
#  'from',
#  'vit',
#  'chennai',
#  'doing',
#  'btech',
#  'for',
#  'last',
#  '4',
#  'years',
#  '.',
#  'I',
#  'have',
#  'been',
#  'placed',
#  'in',
#  'Infosys',
#  'and',
#  'TCS',
#  'digital',
#  ',',
#  'but',
#  'i',
#  'took',
#  'only',
#  'TCS',
#  'as',
#  'it',
#  'had',
#  'a',
#  'higher',
#  'pay',
#  'than',
#  'infosys',
#  '.',
#  'My',
#  'degree',
#  'is',
#  'over',
#  'and',
#  'i',
#  'am',
#  'waiting',
#  'for',
#  'joining',
#  '.',
#  'Thanks',
#  '.',
#  'I',
#  'do',
#  "n't"]

# %%
#document to word
for sentence in document:
  print(word_tokenize(sentence))
# Out:
# ['Hello', 'welcome', ',', 'My', 'name', 'is', 'naman', '.']
# ['I', 'am', 'from', 'vit', 'chennai', 'doing', 'btech', 'for', 'last', '4', 'years', '.']
# ['I', 'have', 'been', 'placed', 'in', 'Infosys', 'and', 'TCS', 'digital', ',', 'but', 'i', 'took', 'only', 'TCS', 'as', 'it', 'had', 'a', 'higher', 'pay', 'than', 'infosys', '.']
# ['My', 'degree', 'is', 'over', 'and', 'i', 'am', 'waiting', 'for', 'joining', '.']
# ['Thanks', '.']
# ['I', 'do', "n't"]

# %%
nltk.wordpunct_tokenize(corpus) #look at don't for diff between punct and tokenize
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'My',
#  'name',
#  'is',
#  'naman',
#  '.',
#  'I',
#  'am',
#  'from',
#  'vit',
#  'chennai',
#  'doing',
#  'btech',
#  'for',
#  'last',
#  '4',
#  'years',
#  '.',
#  'I',
#  'have',
#  'been',
#  'placed',
#  'in',
#  'Infosys',
#  'and',
#  'TCS',
#  'digital',
#  ',',
#  'but',
#  'i',
#  'took',
#  'only',
#  'TCS',
#  'as',
#  'it',
#  'had',
#  'a',
#  'higher',
#  'pay',
#  'than',
#  'infosys',
#  '.',
#  'My',
#  'degree',
#  'is',
#  'over',
#  'and',
#  'i',
#  'am',
#  'waiting',
#  'for',
#  'joining',
#  '.',
#  'Thanks',
#  '.',
#  'I',
#  'don',
#  "'",
#  't']

# %%
from nltk.tokenize import TreebankWordTokenizer
TreebankWordTokenizer().tokenize(corpus) # fullstop not treated as seperate word
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'My',
#  'name',
#  'is',
#  'naman.',
#  'I',
#  'am',
#  'from',
#  'vit',
#  'chennai',
#  'doing',
#  'btech',
#  'for',
#  'last',
#  '4',
#  'years.',
#  'I',
#  'have',
#  'been',
#  'placed',
#  'in',
#  'Infosys',
#  'and',
#  'TCS',
#  'digital',
#  ',',
#  'but',
#  'i',
#  'took',
#  'only',
#  'TCS',
#  'as',
#  'it',
#  'had',
#  'a',
#  'higher',
#  'pay',
#  'than',
#  'infosys.',
#  'My',
#  'degree',
#  'is',
#  'over',
#  'and',
#  'i',
#  'am',
#  'waiting',
#  'for',
#  'joining.',
#  'Thanks.',
#  'I',
#  'do',
#  "n't"]
