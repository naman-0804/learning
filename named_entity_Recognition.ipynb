# %% [markdown]
# <a href="https://colab.research.google.com/github/naman-0804/learning/blob/natural-language-processing/named_entity_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence='''The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel,
whose company specialized in building metal frameworks and structures '''

# %%
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
#   File "/tmp/ipykernel_1807/198403391.py", line 5
#     python -m pip install svgling
#               ^
# SyntaxError: invalid syntax

# %%
# !pip install svgling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 5.5 MB/s eta 0:00:00
# ...

# %%
import nltk
words=nltk.word_tokenize(sentence)
words
# Out:
# ['The',
#  'Eiffel',
#  'Tower',
#  'was',
#  'built',
#  'from',
#  '1887',
#  'to',
#  '1889',
#  'by',
#  'French',
#  'engineer',
#  'Gustave',
#  'Eiffel',
#  ',',
#  'whose',
#  'company',
#  'specialized',
#  'in',
#  'building',
#  'metal',
#  'frameworks',
#  'and',
#  'structures']

# %%
tag_element=nltk.pos_tag(words)
tag_element
# Out:
# [('The', 'DT'),
#  ('Eiffel', 'NNP'),
#  ('Tower', 'NNP'),
#  ('was', 'VBD'),
#  ('built', 'VBN'),
#  ('from', 'IN'),
#  ('1887', 'CD'),
#  ('to', 'TO'),
#  ('1889', 'CD'),
#  ('by', 'IN'),
#  ('French', 'JJ'),
#  ('engineer', 'NN'),
#  ('Gustave', 'NNP'),
#  ('Eiffel', 'NNP'),
#  (',', ','),
#  ('whose', 'WP$'),
#  ('company', 'NN'),
#  ('specialized', 'VBD'),
#  ('in', 'IN'),
#  ('building', 'NN'),
#  ('metal', 'NN'),
#  ('frameworks', 'NNS'),
#  ('and', 'CC'),
#  ('structures', 'NNS')]

# %%
nltk.ne_chunk(tag_element)
# Out:
# Tree('S', [('The', 'DT'), Tree('ORGANIZATION', [('Eiffel', 'NNP'), ('Tower', 'NNP')]), ('was', 'VBD'), ('built', 'VBN'), ('from', 'IN'), ('1887', 'CD'), ('to', 'TO'), ('1889', 'CD'), ('by', 'IN'), Tree('GPE', [('French', 'JJ')]), ('engineer', 'NN'), Tree('PERSON', [('Gustave', 'NNP'), ('Eiffel', 'NNP')]), (',', ','), ('whose', 'WP$'), ('company', 'NN'), ('specialized', 'VBD'), ('in', 'IN'), ('building', 'NN'), ('metal', 'NN'), ('frameworks', 'NNS'), ('and', 'CC'), ('structures', 'NNS')])
