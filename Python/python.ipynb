# %%
name="Naman"
Name="Naman"
print(name)
print(Name)
# Out:
# Naman
# Naman

# %%
x=5
y=7
z=x+y
print(z)
type(z)
# Out:
# 12
# int

# %%
age=32
if age>30:
    print("Hi")
else:
    print("Bye")
# Out:
# Hi
