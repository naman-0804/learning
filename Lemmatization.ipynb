# %% [markdown]
# <a href="https://colab.research.google.com/github/naman-0804/learning/blob/natural-language-processing/Lemmatization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#here the output is calle lemma and it is a root word rather than root stem

# %%
#nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import nltk

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer=WordNetLemmatizer()

# %%
'''
POS
Noun-n
verb-v
adjective-a
adverb-r
'''
lemmatizer.lemmatize("going",pos="v") #goining is a verb so use verb keyword then it works
# Out:
# 'go'
