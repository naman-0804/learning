# %% [markdown]
# <a href="https://colab.research.google.com/github/naman-0804/learning/blob/Langchain_Langraph/data_ingestion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Data ingestion

# %%
# !pip install langchain_community
# !pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.1/378.1 kB 16.9 MB/s eta 0:00:00
# ...

# %%
#Text Loader
from langchain_community.document_loaders import TextLoader
loader=TextLoader('speech.txt')
loader

# %%
text_documents=loader.load() #Has loaded entire speech.txt in 1 document
text_documents
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Speech\n\nGood morning everyone.\n\nToday I would like to speak about the importance of technology in our lives.\n\nTechnology has changed the way we learn, communicate, work, and solve problems. With the internet, cloud computing, artificial intelligence, and modern software, information and tools are available to people faster than ever before.\n\nHowever, technology is only useful when we use it responsibly. We should not depend on technology blindly. We should understand how it works, protect our personal information, and use digital tools to improve our skills and productivity.\n\nAs students and future professionals, we should focus not only on using technology but also on learning how to create it. Developing technical skills, solving real-world problems, and continuously learning will help us adapt to a rapidly changing world.\n\nIn conclusion, technology is a powerful tool. Its impact depends on how we choose to use 
# ...

# %%
##reading a PDF file
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader('attention(1).pdf')
docs=loader.load()
docs
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-08-13T08:29:52+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-08-13T08:29:52+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'attention(1).pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Attention Mechanism\nA practical note for NLP, RNNs, LSTMs and Transformers\n1. Why Attention Was Needed\nIn a basic encoder-decoder RNN/LSTM, the encoder processes the entire input sequence and the\ndecoder traditionally relies heavily on a single final context vector. For long sentences, compressing all\ninformation into one vector can lose important details.\nAttention solves this by allowing the decoder to look at different encoder hidden states and assign\ndifferent importance to them.\n2. Core Idea\nInstead of treating every input word equally, attention calculates a score for each relevant en
# ...
